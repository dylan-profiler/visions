# %%
import pandas as pd

from visions.core.implementations.typesets import visions_complete_set
from visions.core.implementations.types import *
from visions.core.implementations import types
from visions.core.functional import type_inference, type_cast
# %matplotlib inline

# %%
df = pd.DataFrame({
    'str_ints': ['1', '2', '3'],
    'floats': [1.0, 2.0, 3.1]
})

# %%
typeset = visions_complete_set()
typeset.plot_graph()

# %%
type_inference(df, typeset)
# Out:
# {'str_ints': visions_integer, 'floats': visions_float}

# %%
from numpy.core import ComplexWarning
import pandas as pd
import warnings

def test(x):
    warnings.filterwarnings("ignore", category=ComplexWarning)
    x.astype(float)

x = pd.Series([(1+2j)])

# %%
x.astype(float)
# Out:
# /Users/cn186324/anaconda3/envs/temp3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:729: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# 0    1.0
# dtype: float64

# %%
test(x)

# %%
with warnings.catch_warnings() as t:
    warnings.simplefilter("ignore")
    x.astype(float)

# %%
warnings.
