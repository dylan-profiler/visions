# %%
import pandas as pd

from tenzing.core.model import tenzing_complete_set
from tenzing.core.summaries.summary import summary
from tenzing.core.model.functional import type_inference, type_cast
# %matplotlib inline

# %%
# Load dataset
df = pd.read_csv(
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
)


df.head()

df['Age'] = pd.Categorical(df['Age'], ordered=True)

# %%
typeset = tenzing_complete_set()
typeset.plot_graph()

# %%
inferred_types = type_inference(df, typeset)
inferred_types
# Out:
# {'PassengerId': tenzing_integer,
#  'Survived': tenzing_integer,
#  'Pclass': tenzing_integer,
#  'Name': tenzing_string,
#  'Sex': tenzing_string,
#  'Age': tenzing_ordinal,
#  'SibSp': tenzing_integer,
#  'Parch': tenzing_integer,
#  'Ticket': tenzing_string,
#  'Fare': tenzing_float,
#  'Cabin': tenzing_string,
#  'Embarked': tenzing_string}

# %%
cast_df, cast_types = type_cast(df, typeset)
cast_types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a6c2c74c1f71> in <module>
# ----> 1 cast_df, cast_types = type_cast(df, typeset)
#       2 cast_types
#
# ~/repos/tenzing/src/tenzing/core/model/functional.py in type_cast(df, typeset)
#       4
#       5 def type_cast(df: pd.DataFrame, typeset: tenzingTypeset) -> tenzingTypeset:
# ----> 6     cast_df = typeset.cast_to_inferred_types(df)
#       7     cast_types = {column: typeset.get_series_type(df[column]) for column in df.columns}
#       8     return cast_df, cast_types
#
# ~/repos/tenzing/src/tenzing/core/model/typeset.py in cast_to_inferred_types(self, df)
#     188
#     189     def cast_to_inferred_types(self, df: pd.DataFrame) -> pd.DataFrame:
# --> 190         return pd.DataFrame({col: self.cast_series(df[col]) for col in df.columns})
#     191
# ...
